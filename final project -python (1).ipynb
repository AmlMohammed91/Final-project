# %%
import pandas as pd

# %%
df = pd.read_csv(r'D:\Data Analytics\Superstore Sales Dataset.csv')

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df['Postal Code'].hist()
# Out:
# <Axes: >

# %%
df.sample(n=20)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2123    2124  CA-2018-167381  22/09/2018  24/09/2018    Second Class
# 1869    1870  CA-2017-148201  26/08/2017  29/08/2017    Second Class
# 5434    5435  CA-2016-160171  19/10/2016  24/10/2016  Standard Class
# 943      944  CA-2016-120880  29/05/2016  03/06/2016  Standard Class
# 9315    9316  CA-2017-161907  05/04/2017  09/04/2017  Standard Class
# 5628    5629  CA-2018-148810  26/06/2018  01/07/2018  Standard Class
# 9048    9049  CA-2018-137463  16/12/2018  20/12/2018    Second Class
# 7317    7318  CA-2018-158120  17/11/2018  21/11/2018  Standard Class
# 5005    5006  CA-2016-158659  10/11/2016  14/11/2016    Second Class
# 7349    7350  CA-2018-142125  21/10/2018  27/10/2018  Standard Class
# 7167    7168  CA-2015-117464  22/07/2015  24/07/2015    Second Class
# 2927    2928  CA-2018-158106  04/06/2018  10/06/2018  Standard Class
# 5853    5854  US-2015-138835  10/09/2015  14/09/2015  Standard Class
# ...

# %%
df.sample(frac=0.50)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2772    2773  CA-2018-158967  10/12/2018  12/12/2018     First Class
# 240      241  CA-2017-157749  04/06/2017  09/06/2017    Second Class
# 5516    5517  US-2017-138408  18/11/2017  21/11/2017    Second Class
# 2212    2213  CA-2018-107874  21/11/2018  25/11/2018  Standard Class
# 301      302  CA-2017-142545  28/10/2017  03/11/2017  Standard Class
# ...      ...             ...         ...         ...             ...
# 2518    2519  CA-2017-124352  15/10/2017  21/10/2017  Standard Class
# 2202    2203  CA-2016-138002  06/09/2016  12/09/2016  Standard Class
# 9645    9646  US-2018-107979  08/06/2018  13/06/2018  Standard Class
# 1433    1434  CA-2015-120768  19/12/2015  21/12/2015    Second Class
# 5506    5507  US-2017-162026  08/10/2017  08/10/2017        Same Day
#
#      Customer ID     Customer Name      Segment        Country  \
# 2772    BT-11680    Brian Thompson     Consumer  United States
# ...

# %%
df['Postal Code'].fillna('Unknown',inplace=True)
# Out:
# C:\Users\MOHAMED SALAMA\AppData\Local\Temp\ipykernel_5288\2159489158.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['Postal Code'].fillna('Unknown',inplace=True)

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
#total_customers
total_customers = df['Customer ID'].nunique()

# %%
print(total_customers)
# Out:
# 793

# %%
# Total sales
Total_sales= round(df['Sales'].sum(),2)

# %%
print(Total_sales)
# Out:
# 2261536.78

# %%
#Total orders
total_orders= df['Order ID'].nunique()

# %%
print(total_orders)
# Out:
# 4922

# %%
sales_per_city_top10 = df.groupby('City')['Sales'].sum().sort_values(ascending=False).head(10)

# %%
print(sales_per_city_top10)
# Out:
# City
# New York City    252462.5470
# Los Angeles      173420.1810
# Seattle          116106.3220
# San Francisco    109041.1200
# Philadelphia     108841.7490
# Houston           63956.1428
# Chicago           47820.1330
# San Diego         47521.0290
# Jacksonville      44713.1830
# Detroit           42446.9440
# Name: Sales, dtype: float64

# %%
df.to_excel(r'D:\Data Analytics\cleaned_superstore sales.xlsx', index=False)
